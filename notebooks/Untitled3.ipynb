# %%
import pandas as pd
import json

# %%
import pyarrow.parquet as pq

# %%
table = pq.read_table("./depths.parquet")

# %%
df = table.to_pandas()
# Out:
# /home/thorad/.local/lib/python3.6/site-packages/pyarrow/pandas_compat.py:752: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels, = index.labels

# %%
df
# Out:
# Empty DataFrame
# Columns: [event_type, exchange, base_asset, quote_asset, symbol, time, event_id, partition_id, side, price, quantity]
# Index: []

# %%
df[['close_price']].plot(figsize=(60,40), fontsize=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d60cf01e56b> in <module>()
# ----> 1 df[['close_price']].plot(figsize=(60,40), fontsize=50)
#
# NameError: name 'df' is not defined

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 1500)
pd.set_option('display.width', 1000)

# %%
data = []
with open("/home/thorad/Core/Projects/AxiomPython/pipe/beam-temp-output_fivesec-4ee3e956827a11e98fac303a643c3d81/1a8e66c3-90fb-48e5-9615-fba777a44d6c.output_fivesec") as f:
    for line in f:
        data.append(json.loads(line))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-522147c28a91> in <module>
#       1 data = []
# ----> 2 with open("/home/thorad/Core/Projects/AxiomPython/pipe/beam-temp-output_fivesec-4ee3e956827a11e98fac303a643c3d81/1a8e66c3-90fb-48e5-9615-fba777a44d6c.output_fivesec") as f:
#       3     for line in f:
#       4         data.append(json.loads(line))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/thorad/Core/Projects/AxiomPython/pipe/beam-temp-output_fivesec-4ee3e956827a11e98fac303a643c3d81/1a8e66c3-90fb-48e5-9615-fba777a44d6c.output_fivesec'

# %%
d = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
d.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-25ab21267978> in <module>
# ----> 1 d.columns
#
# NameError: name 'd' is not defined

# %%
del d['count']

# %%
df[].fillna(method='ffill', axis=0)
