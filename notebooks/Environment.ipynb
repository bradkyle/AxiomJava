# %%
import pyarrow.parquet as pq
import pandas as pd
import pyarrow as pa
import sonnet as snt
import tensorflow as tf
import numpy as np
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
window_size = 90
df = pq.read_table('../data/environment/data.parquet').to_pandas()

# %%
dta = df.reset_index().set_index(['index','time', 'quote_asset']).drop(columns=['base_asset', 'level_0'])

# %%
len(dta.columns)
# Out:
# 253

# %%
#closePrice, closeQty, vwap, ask_0_closePrice, ask_0_closeQty, bid_0_closePrice, bid_0_closeQty

# %%
obs = [
    {
        'o': dta[s:s+90,:], 
        'y': dta[s+91,:], 
        'c':0.1, 
        'l':0.1, 
        'v':13, 
        'last_w': 8, 
        'setw': 6, 
    } for s in range(len(dta)-1) # batch size
]

# %%
for o in obs:
    pass

# %%
for es in range(1000):
    
    x, y, last_w, setw = self.next_batch()
    
    self._agent.train(x, y, c, last_w=last_w, setw=setw)
