# %%
import time 
import numpy as np
import pandas as pd 
import tensorflow as tf
import random

# %%
depths = []
trades = []

# %%
for l in range(5):
    for _ in range(5):
        depths.append({
            "side": "bid",
            "level": l,
            "time": time.time(),
            "price": random.random(),
            "quantity": random.random()
        })

# %%
for _ in range(5):
    trades.append({
        "side": "sell",
        "time": time.time(),
        "price": random.random(),
        "quantity": random.random()
    })

# %%
dep = pd.DataFrame(depths).sort_values(by=['time']).groupby('level')

# %%
s = pd.DataFrame(trades).sort_values(by=['time']).groupby('side')

# %%
d = dep

# %%
acc = {}
for i in range(20):
        acc[random.random()] = random.random()

# %%
bids = [{"level": l, "price":p, "quantity": p} for l, (p, q) in enumerate(sorted(acc.items(), key=lambda e: e[0], reverse=True))][:10]

# %%
asks = [{"level": l, "price":p, "quantity": p} for l, (p, q) in enumerate(sorted(acc.items(), key=lambda e: e[0], reverse=False))][:10]

# %%
asks
# Out:
# [{'level': 0, 'price': 0.021370198013802355, 'quantity': 0.021370198013802355},
#  {'level': 1, 'price': 0.11202441316818024, 'quantity': 0.11202441316818024},
#  {'level': 2, 'price': 0.1134643672159048, 'quantity': 0.1134643672159048},
#  {'level': 3, 'price': 0.2034035861793324, 'quantity': 0.2034035861793324},
#  {'level': 4, 'price': 0.20995541266840378, 'quantity': 0.20995541266840378},
#  {'level': 5, 'price': 0.3127516799239435, 'quantity': 0.3127516799239435},
#  {'level': 6, 'price': 0.3199395864902872, 'quantity': 0.3199395864902872},
#  {'level': 7, 'price': 0.3610175012432806, 'quantity': 0.3610175012432806},
#  {'level': 8, 'price': 0.412631209548704, 'quantity': 0.412631209548704},
#  {'level': 9, 'price': 0.42722960533817833, 'quantity': 0.42722960533817833}]

# %%
bids
# Out:
# [{'level': 0, 'price': 0.9803847694517538, 'quantity': 0.9803847694517538},
#  {'level': 1, 'price': 0.9270299955623993, 'quantity': 0.9270299955623993},
#  {'level': 2, 'price': 0.9067398807876266, 'quantity': 0.9067398807876266},
#  {'level': 3, 'price': 0.8906186888862806, 'quantity': 0.8906186888862806},
#  {'level': 4, 'price': 0.770706570148731, 'quantity': 0.770706570148731},
#  {'level': 5, 'price': 0.6619436650530977, 'quantity': 0.6619436650530977},
#  {'level': 6, 'price': 0.5250281176443155, 'quantity': 0.5250281176443155},
#  {'level': 7, 'price': 0.46189323874676935, 'quantity': 0.46189323874676935},
#  {'level': 8, 'price': 0.4598859336311636, 'quantity': 0.4598859336311636},
#  {'level': 9, 'price': 0.43200474444976855, 'quantity': 0.43200474444976855}]

# %%
len(agg(dep, label="ask").keys())
# Out:
# 200

# %%
# Out:
# 460

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-f20712fbdf91> in <module>
# ----> 1 sums[['type', 'side', 'price', 'quantity']]
#
# ~/.conda/envs/axiom/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~/.conda/envs/axiom/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
# ...

# %%
sdf[sdf['type']=='level'].groupby(['type', 'side', 'level']).mean()
# Out:
#                      price  quantity          time
# type  side level
# level ask  0.0    0.439074  0.576992  1.559048e+09
#            1.0    0.394455  0.723973  1.559048e+09
#            2.0    0.354137  0.488224  1.559048e+09
#            3.0    0.425287  0.374336  1.559048e+09
#            4.0    0.591468  0.487528  1.559048e+09
#            5.0    0.624395  0.610979  1.559048e+09
#            6.0    0.554957  0.468835  1.559048e+09
#            7.0    0.333460  0.721732  1.559048e+09
#            8.0    0.491593  0.654476  1.559048e+09
#            9.0    0.507404  0.524790  1.559048e+09
#       bid  0.0    0.360853  0.741377  1.559048e+09
#            1.0    0.485717  0.617944  1.559048e+09
#            2.0    0.381500  0.578630  1.559048e+09
#            3.0    0.609352  0.511558  1.559048e+09
#            4.0    0.393264  0.481395  1.559048e+09
#            5.0    0.522118  0.364461  1.559048e+09
#            6.0    0.603968  0.562281  1.559048e+09
# ...
