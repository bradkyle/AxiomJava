# %%
import numpy as np

# %%
current_value = 1
current_pv = np.array([0.5, 0.5])
target_pv = np.array([0.75, 0.25])

# %%
delta_pv = target_pv - current_pv

# %%
maximum_leverage = 5

# %%
delta_pv = np.reshape(delta_pv, [2])

# %%
delta_pv
# Out:
# array([ 0.25, -0.25])

# %%
longs = delta_pv[0]


shorts = delta_pv[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-9eec0431980f> in <module>()
#       1 longs = delta_pv[0]
# ----> 2 shorts = delta_pv[1]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
for lng in longs:
    print(lng)
for sht in shorts:
    print(sht)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-7fa925d9fe85> in <module>()
# ----> 1 for lng in longs:
#       2     print(lng)
#       3 for sht in shorts:
#       4     print(sht)
#
# TypeError: 'numpy.float64' object is not iterable
